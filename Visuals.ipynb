# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matminer.datasets import load_dataset
import pandas as pd
from monty.serialization import loadfn, dumpfn
import numpy as np
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as patches

from pymatgen.ext.matproj import MPRester
from matminer.data_retrieval.retrieve_MP import MPDataRetrieval

# %%
df = pd.read_excel('./HEA_sheet_for_YSP.xlsx', sheet_name='HEA')
df = df.rename(columns={"HEA Basic Information":"HEA Formula", "Unnamed: 1":"Number of Elements", "Unnamed: 2":"Is Equimolar", "Unnamed: 3":"Crystal Structure", "Synthesis Information":"Reported Precursors", "Unnamed: 5":"Synthesis Method", "Unnamed: 6":"Synthesis Description", "References":"Reported HEA Reference", "Unnamed: 8":"Year of Publication", "Propetry":"Formation Energy (eV/atom)"})
rows = []
for x in range (55):
    rows.append("row" + str(x))
df.index = rows
df = df.drop('row0')
df
# Out:
#                 HEA Formula Number of Elements  \
# row1                AlCuAu                   3
# row2                CoCuAu                   3
# row3                CoCuPd                   3
# row4                CoNiPd                   3
# row5                CoPdAu                   3
# row6                CoPtAu                   3
# row7                CrCuPt                   3
# row8                CrPdAu                   3
# row9                CuAgPd                   3
# row10                CuAgPt                  3
# row11                CuIrPd                  3
# row12                CuNiAu                  3
# row13               CuNiPd                   3
# row14               CuNiPt                   3
# row15               CuPdAu                   3
# row16               CuPtAu                   3
# row17               FeCoPd                   3
# row18               FeCoRh                   3
# row19               FeCuAu                   3
# row20               FeCuPt                   3
# row21               FePdAu                   3
# row22               MnCoRh                   3
# row23               MnCrPt                   3
# row24                MnFePt                  3
# row25               MnFeRh                   3
# row26               NiIrPd                   3
# row27               TiCuPd                   3
# row28            PtPdFeCoNi                  5
# row29  MnCoNiCuRhPdSnIrPtAu                 10
# row30            NiCoCuFePt                  5
# row31          PtIrCuInGaPb                  6
# row32            CoCrFeMnNi                  5
# row33            PdPtRhIrRu                  5
# row34              TiNbTaZr                  4
# row35            PtCoNiRuIr                  5
# row36            FeMnCoCrAl                  5
# row37            AlFeCrCoNi                  5
# row38            CrFeCoNiMo                  5
# row39            AlCoCrFeNi                  5
# row40            PtPdIrRuAg                  5
# row41            CoNiCuRuPd                  5
# row42          PtIrFeNiCoCe                  6
# row43            CoCrCuNiAl                  5
# row44   PtCoCuRhFeIrRuNiPdW                 10
# row45            CoCrFeNiAl                  5
# row46           AlCrFeMnNiW                  6
# row47          AlCoCrFeNiMn                  6
# row48            CoCrFeNiMn                  5
# row49             AlTiZrVNb                  5
# row50            FeCoNiCrCu                  5
# row51            FeCoNiAlSi                  5
# row52            MnFeCoNiCu                  5
# row53          PtAlMnCoNiCu                  6
# row54            IrPdPtRhRu                  5
#
#                                             Is Equimolar  \
# row1                                                 NaN
# row2                                                 YES
# row3                                                  NO
# row4   Equiatomic binary, ternary and quinary alloys ...
# row5               YES (equimolar amounts of precursors)
# row6   YES (Prepared Co0.33Pt0.33Au0.33 but also prep...
# row7                                                 NaN
# row8                                                  NO
# row9                                                 NaN
# row10                                                NaN
# row11                                                 NO
# row12                                                 NO
# row13                                                NaN
# row14                                                NaN
# row15                                                 NO
# row16                                                NaN
# row17                                                YES
# row18                                                 NO
# row19                                                 NO
# row20                                                 NO
# row21                                                 NO
# row22                                                 NO
# row23                                                NaN
# row24                                                NaN
# row25                                                 NO
# row26                                                 NO
# row27                                                NaN
# row28                                                YES
# row29                                                YES
# row30                                                NaN
# row31                                                 NO
# row32                                                NaN
# row33                                                NaN
# row34                                                YES
# row35                                                NaN
# row36                                                 NO
# row37                                                NaN
# row38                                                YES
# row39                                                YES
# row40                                                 NO
# row41                                                YES
# row42                                                NaN
# row43                                                NaN
# row44                                                NaN
# row45                                                NaN
# row46                                                NaN
# row47                                                YES
# row48                                                YES
# row49                                                NaN
# row50                                                NaN
# row51                                                 NO
# row52                                                YES
# row53                                                 NO
# row54                                                YES
#
#                                        Crystal Structure  \
# row1                                                 NaN
# row2                                                 NaN
# row3                                                 NaN
# row4                                               Cubic
# row5   The crystal structure of NCs were characterize...
# row6   The crystal structure of the CoPtAu nanopartic...
# row7                                                 NaN
# row8                                                 NaN
# row9                                                 NaN
# row10  The XRD analyses show that the crystal structu...
# row11  The average diameter of Pd58Cu32Ir10 catalysts...
# row12                                                NaN
# row13  The phase composition and structure of CNP ele...
# row14  The representative TEM images (Figure S2a) sho...
# row15  The fast fourier transform is applied to calcu...
# row16                                                NaN
# row17                                                NaN
# row18                                              Cubic
# row19                                                NaN
# row20                                                NaN
# row21  Crystallographic phases were characterized by ...
# row22                                                NaN
# row23                                                NaN
# row24  The crystal structures of the obtained NCs wer...
# row25  Powder X-ray diffraction (XRD) measurements we...
# row26  Figure 1 shows the XRD patterns of the prepare...
# row27  The spectra and designation of crystallographi...
# row28  After we studied the synthesis process, we fur...
# row29  The high-resolution scanning transmission elec...
# row30  Moreover, as shown in Figure 2g, the fast Four...
# row31  The structural features of the senary PtIrCuIn...
# row32                                                fcc
# row33                                                fcc
# row34                                                NaN
# row35                                                fcc
# row36                                                bcc
# row37                                                NaN
# row38                                                fcc
# row39                             mixture of fcc and bcc
# row40                                                fcc
# row41                                                NaN
# row42                                                fcc
# row43                                                fcc
# row44                                                fcc
# row45                                                bcc
# row46                     major bcc and minor fcc phases
# row47                                                bcc
# row48                                                fcc
# row49                                                bcc
# row50                                                fcc
# row51  transition from an FCC phase to a BCC phase as...
# row52                                                fcc
# row53                                                fcc
# row54                                                fcc
#
#                                      Reported Precursors  \
# row1   AlCuAu, AuAgPd, Crystal Silicon Blades, Linear...
# row2   K3Fe(CN)6, CuCl2·2H2O, K4Fe(CN)6, KCl, NaH2PO4...
# row3   N2, Co2+, Potassium Citrate, NaBH4, Co Nanosph...
# row4   Ni, Co, Cr, Fe, Pd, water-cooled copper mold, ...
# row5   P123, N2, H2O,  KOH, CH3OH, H2SO4, NaBH4, K2Pd...
# row6   Au(OOCCH3)3, Co(acac)2, Pt(acac)2, PEO-PPO-PEO...
# row7   glycine, PVP, NaI, H2PtCl6, CuCl2, CrCl3, etha...
# row8                                        NaBH4, water
# row9   CuBr, 250 mL three-necked flask, vacuum, PdCl2...
# row10  AgNO3, Cu(NO3)2·3H2O, K2PtCl4, Na2PdCl4, branc...
# row11  Na2PdCl4, CuCl2·2H2O, W(CO)6, Fe(CH3COO)2, pol...
# row12  polystyrene-b-polyethylene oxide (PS-b-PEO), t...
# row13  substrate of Ni foam, C3H6O (acetone), HCl, de...
# row14  H2PtCl6, NiCl2, CuCl2, Polyvinylpyrrolidone (P...
# row15  Cu(acac)2, Pd(acac)2, PVPK30,  C2H6O, AuCl3·4H...
# row16  Cu(NO₃)₂·3H₂O, NaOH pellets, C2H8N2 (Ethylened...
# row17  FeCl3·6H2O, CoCl2·6H2O, PdCl2, IrO2, Fe(NO3)3·...
# row18  FeCl2·4H2O, CoCl2·6H2O, PVP, deionized water, ...
# row19  Fe powder with sizes below 10 μm, Ag, Au with ...
# row20  Alloy films with thickness 0.5 and 1 uM, Si(10...
# row21  high purity Fe (99.5%), Au50Pd50 (at.%) alloy,...
# row22  RuCl3∙xH2O, Co(NO3)2∙6H2O, Mn(NO3)2, NaCO3, de...
# row23                                                NaN
# row24  PVP, glycine, H2PtCl6, MnCl2, FeCl3, Teflon-li...
# row25  silica support, synthetic air, Rh, SiO2, RhMn,...
# row26  Vulcan XC-72R carbon black, HNO3 (nitric acid)...
# row27  cylindrical ingots, vacuum furnace, inert Ar a...
# row28  FeCl3, CoCl2, NiCl2, H2PtCl6, PdCl2, rGO-570 f...
# row29  metal chloride salts precursors, 1,10-Phenanth...
# row30  metal salts, de-ionized water, 10% H2/90% Ar g...
# row31  nuclei/seed surfaces, H•, N-dimethylformamide ...
# row32                                                NaN
# row33  Metal powders of elements (Pd, Pt, Rh, Ir, Ru)...
# row34  TiO2, Nb2O5, Ta2O5, ZrO2, HfO2(?), isopropanol...
# row35  Metal acetylacetone, carbon black, oleylamine ...
# row36             Fe-Mn alloy, Co, Cr, Al, Si substrates
# row37  high power Ytterbium, Al powder, Fe powder, Cr...
# row38  (Ar-H2 or Ne), Ar, metal power mix (5 elements),
# row39   He atmosphere, vacuum, resistance furnace, ingot
# row40  AgNO3, FeCl3·6H2O, Pt(acac)2, Pd(acac)2, Ir(ac...
# row41  TiO2, Al2O3, MgO, RuCl3·nH2O, Cu(NO3)2·3H2O, C...
# row42             carbon nanofiber membranes, flashlight
# row43                                nitrate-citric acid
# row44  salts (not specifcied), deionized water, graph...
# row45  Metal powders of elements (Co, Cr, Fe, Ni, Al)...
# row46  C7H8, Fritsch pulverisette 6 planetary ball mi...
# row47  Powders of elements (Al, Co, Cr, Fe, Ni, Mn), ...
# row48  laser beam, ethanol, micropowders of the singl...
# row49  TiO2, ZrO2, V2O5, Nb2O5, CaO, CaF2, Al2O3, cor...
# row50  powders of elements (Fe, Co, Ni, Cr, Cu), ferr...
# row51                                                NaN
# row52  MnCl2, FeCl2, CoCl2, NiCl2, CuCl2, Ar-filled c...
# row53  PtCl4, Al(NO3)3·9H2O, Mn(NO3)2·4H2O, Ni(NO3)2·...
# row54  Li metal, naphthalene, dioxidetetrahydrofuran,...
#
#                                         Synthesis Method  \
# row1                       Atomic layer deposition (ALD)
# row2                                   electrodeposition
# row3                          electrochemical deposition
# row4                                   arc-melt (Ar gas)
# row5                         successive reduction method
# row6                         sequential Reduction Method
# row7                hydrothermal or solvothermal method
# row8   impregnation route followed by subsequent sodi...
# row9                           liquid chemical reduction
# row10                                      aqueous-phase
# row11                                 chemical reduction
# row12                         electrochemical deposition
# row13                          liquid chemical reduction
# row14                hydrothermal or solvothermal method
# row15                Wet chemistry (CuPd NP +AuCl3·4H2O)
# row16                        galvanic replacement method
# row17                          liquid chemical reduction
# row18              hydrothermal (Fe3Co7@NG + RhCl3-3H2O)
# row19                                       ball-milling
# row20        radio frequency magnetron sputtering (film)
# row21  homogenized and quench (cast from high purity ...
# row22                            co-precipitation method
# row23                                                NaN
# row24               hydrothermal or solvothermal method
# row25             incipient wetness impregnation method.
# row26  Reductive Deposition (functionalized carbon bl...
# row27                preticipate from Ni-Ti-Cu-Pd Alloys
# row28                                  microwave heating
# row29                          fast moving bed pyrolysis
# row30                                 carbothermal shock
# row31                   wet-chemical hydrothermal method
# row32                              high-pressure torsion
# row33                                  one-pot synthesis
# row34         electrochemical reduction in a molten salt
# row35            high-temperature liquid shock synthesis
# row36               combinatorial sputtering and casting
# row37                          laser surface engineering
# row38                             thermal plasma process
# row39                                  arc-melt (He gas)
# row40                                hydrothermal method
# row41                                 hydrogen spillover
# row42                                flash thermal shock
# row43                             sol-gel autocombustion
# row44  spray drying technique combined with the therm...
# row45                             spark plasma sintering
# row46                                       ball milling
# row47                                       ball milling
# row48             kinetically controlled laser synthesis
# row49  aluminothermal reduction of metals from their ...
# row50                                     laser cladding
# row51                                  ammonia synthesis
# row52                            laser thermal reduction
# row53                                  microwave heating
# row54                  continuous flow-reactor synthesis
#
#                                    Synthesis Description  \
# row1   Two fcc films, AlCuAu alloy and AuAgPd solid-s...
# row2   The electrode was first polished with alumina ...
# row3                                                 NaN
# row4   Equiatomic binary, ternary and quinary alloys ...
# row5   The CoAuPd-1 NCs are synthesized through co-re...
# row6   Gold acetate (Au(OOCCH3)3)⁠, cobalt (II) acety...
# row7   Typically, 303.4 mg of glycine, 180.0 mg of po...
# row8   CrAuPd/N-SiO2 can reproducibly be prepared thr...
# row9   Cu NPs of three different morphologies were sy...
# row10  To produce AgPt nanoparticles, 20 mg of BPEI w...
# row11  First, 10 mg Na2PdCl4, 5 mg CuCl2·2H2O, 30 mg ...
# row12  Polymeric micelles assembly was first prepared...
# row13  A facile hydrothermal treatment was used to sy...
# row14  For the synthesis of Pt–Ni–Cu alloy NCs, 220 m...
# row15  The preparation procedure of CuPdAu/C catalyst...
# row16  Cu NWs were prepared as reported earlier using...
# row17  The synthesis of FeCoPd nanoparticles was carr...
# row18  RhFeCo@NG hybrids were fabricated in two steps...
# row19  In the Fe-based alloys we have started using F...
# row20                  Formatting issue (II. Experiment)
# row21  The alloy investigated in the present study is...
# row22  The trimetallic Ru-CoMn was prepared by a co-p...
# row23                                                NaN
# row24  Typically, PVP (220 mg), glycine (38 mg), H2Pt...
# row25  The four different catalysts were synthesized ...
# row26  Vulcan XC-72R carbon black was obtained from C...
# row27  The alloys were melted by VIM as cylindrical 4...
# row28  As a demonstration, we synthesized the PtPdFeC...
# row29  As-proof-concept, the denary (MnCoNiCuRhPdSnIr...
# row30  Here, synthesis of NiCoCuFePt HEA nanoparticle...
# row31  We introduce H• confined on nuclei/seed surfac...
# row32                                                NaN
# row33  We first conducted the one-pot synthesis to ex...
# row34  Powders of TiO2, Nb2O5, Ta2O5 and ZrO2 were us...
# row35  Pt-based HEA-NP catalysts were synthesized via...
# row36  FeMnCoCrAl HEA thin films were grown at room t...
# row37                                   formatting error
# row38  In a typical synthesis run, a mixture of five ...
# row39  The master alloy under consideration with the ...
# row40  The Ag nanowires (NWs) were synthesized by usi...
# row41  TiO2 (0.5 g) was dispersed in distilled water ...
# row42  First, carbon nanofibers (CNF) membranes, whic...
# row43                                                NaN
# row44  In this work, appropriated precursors salts we...
# row45  Metal powders of Co, Cr, Fe, Ni, Al with purit...
# row46  Powder sample is prepared using high-energy ba...
# row47  High purity (>99 wt%) elemental powders of Al,...
# row48  Picosecond-pulsed laser ablation of CoCrFeMnNi...
# row49  In the experiments, we used batches oriented t...
# row50  The equiatomic Fe, Co, Ni, Cr, and Cu of the p...
# row51                                                NaN
# row52  Fig. 1d shows the schematic diagram for the pr...
# row53  These nanocatalysts have different composition...
# row54                                   formatting error
#
#                                   Reported HEA Reference Year of Publication  \
# row1        https://doi.org/10.1016/j.matdes.2020.108802                2020
# row2       https://doi.org/10.3390/pharmaceutics15030876                2023
# row3              https://doi.org/10.1021/acsami.7b17731                2018
# row4          https://doi.org/10.1007/s12540-023-01500-z                2023
# row5      https://doi.org/10.1016/j.jpowsour.2018.11.044                2019
# row6                   https://doi.org/10.1063/1.3072750                2009
# row7           https://doi.org/10.1016/j.ces.2023.119486                2024
# row8                  https://doi.org/10.1039/C5CC02371H                2015
# row9             https://doi.org/10.1021/acsnano.2c01840                2022
# row10                 https://doi.org/10.3390/ma13020254                2020
# row11     https://doi.org/10.1016/j.ijhydene.2020.07.150                2020
# row12             https://doi.org/10.1002/smtd.201800283                2018
# row13    https://doi.org/10.1016/j.electacta.2018.12.185                2019
# row14      https://doi.org/10.1021/acs.chemmater.5b02575                2015
# row15     https://doi.org/10.1016/j.ijhydene.2016.05.224                2016
# row16    https://doi.org/10.1016/j.electacta.2018.06.094                2018
# row17                 https://doi.org/10.1039/D2TA04436F                2022
# row18             https://doi.org/10.1021/acsanm.1c03128                2021
# row19      https://doi.org/10.1016/j.jallcom.2011.11.094                2012
# row20                  https://doi.org/10.1063/1.2756631                2007
# row21          https://doi.org/10.1007/s10853-008-2752-5                2008
# row22       https://doi.org/10.1016/j.apcatb.2020.119840                2021
# row23                  https://doi.org/10.1109/20.908543                2000
# row24                https://doi.org/10.1039/C8NR10231G                 2019
# row25                https://doi.org/10.1039/D1CY00421B                 2021
# row26          https://doi.org/10.1007/s10008-018-3908-0                2018
# row27                https://doi.org/10.3390/met11091387                2021
# row28  https://pubs.acs.org/doi/full/10.1021/acsnano....                2021
# row29  https://www.nature.com/articles/s41467-020-159...                2023
# row30  https://pubs.acs.org/doi/full/10.1021/acs.lang...                2020
# row31  https://pubs.acs.org/doi/full/10.1021/jacs.4c1...                2025
# row32           https://www.mdpi.com/2075-4701/11/8/1263                2021
# row33  https://www.science.org/doi/full/10.1126/sciad...                2023
# row34  https://www.sciencedirect.com/science/article/...                2017
# row35  https://pubs.acs.org/doi/full/10.1021/acsnano....                2024
# row36  https://www.sciencedirect.com/science/article/...                2017
# row37  https://www.sciencedirect.com/science/article/...                2015
# row38  https://www.nature.com/articles/s41467-024-457...                2024
# row39  https://www.sciencedirect.com/science/article/...                2017
# row40  https://pubs.acs.org/doi/full/10.1021/jacs.2c0...                2022
# row41  https://www.nature.com/articles/s41467-021-242...                2021
# row42  https://advanced.onlinelibrary.wiley.com/doi/f...                2023
# row43  https://www.nature.com/articles/s41598-017-036...                2017
# row44  https://pubs.acs.org/doi/full/10.1021/acsnano....                2022
# row45  https://www.sciencedirect.com/science/article/...                2014
# row46  https://www.sciencedirect.com/science/article/...                2020
# row47  https://www.sciencedirect.com/science/article/...                2018
# row48  https://pubs.rsc.org/en/content/articlehtml/20...                2019
# row49  https://link.springer.com/article/10.1134/S003...                2022
# row50  https://www.sciencedirect.com/science/article/...                2011
# row51  https://pubs.acs.org/doi/full/10.1021/jacs.5c0...                2025
# row52  https://www.sciencedirect.com/science/article/...                2024
# row53  https://www.sciencedirect.com/science/article/...                2024
# row54  https://pubs.acs.org/doi/full/10.1021/jacs.2c0...                2022
#
#       Formation Energy (eV/atom)
# row1                         NaN
# row2                         NaN
# row3                         NaN
# row4                         NaN
# row5                         NaN
# row6                         NaN
# row7                         NaN
# row8                         NaN
# row9                         NaN
# row10                        NaN
# row11                        NaN
# row12                        NaN
# row13                        NaN
# row14                        NaN
# row15                        NaN
# row16                        NaN
# row17                        NaN
# row18                        NaN
# row19                        NaN
# row20                        NaN
# row21                        NaN
# row22                        NaN
# row23                        NaN
# row24                        NaN
# row25                        NaN
# row26                        NaN
# row27                        NaN
# row28                        NaN
# row29                        NaN
# row30                        NaN
# row31                        NaN
# row32                        NaN
# row33                        NaN
# row34                        NaN
# row35                        NaN
# row36                        NaN
# row37                        NaN
# row38                        NaN
# row39                        NaN
# row40                        NaN
# row41                        NaN
# row42                        NaN
# row43                        NaN
# row44                        NaN
# row45                        NaN
# row46                        NaN
# row47                        NaN
# row48                        NaN
# row49                        NaN
# row50                        NaN
# row51                        NaN
# row52                        NaN
# row53                        NaN
# row54                        NaN

# %%
from pymatgen.core.composition import Composition

formulas = df["HEA Formula"]
element_counts = {}
for formula in formulas:
    composition = Composition(formula)
    elements = composition.elements
    for element in elements:
        element = str(element)
        if not element in element_counts:
            element_counts[element] = 1
        else:
            element_counts[element] +=1
    
print(element_counts)


sorted_items = sorted(element_counts.items(), key=lambda item: item[1], reverse=True)
elements = [item[0] for item in sorted_items]
counts = [item[1] for item in sorted_items]

# Create the bar graph directly using seaborn.barplot
plt.figure(figsize=(9, 6)) # Adjust figure size as needed
sns.barplot(x=elements, y=counts, palette="mako")

plt.title('Frequency of Elements in HEAs')
plt.xlabel('Element')
plt.ylabel('Counts')
plt.grid(axis='y', linestyle='--', alpha=0.7) # Optional: add grid lines
plt.show()
# Out:
# {'Al': 11, 'Cu': 24, 'Au': 11, 'Co': 28, 'Pd': 19, 'Ni': 25, 'Pt': 19, 'Cr': 14, 'Ag': 3, 'Ir': 10, 'Fe': 23, 'Rh': 7, 'Mn': 12, 'Ti': 3, 'Sn': 1, 'In': 1, 'Ga': 1, 'Pb': 1, 'Ru': 6, 'Nb': 2, 'Ta': 1, 'Zr': 2, 'Mo': 1, 'Ce': 1, 'W': 2, 'V': 1, 'Si': 1}
# /var/folders/7c/90tth4h53mnglfwy8ww1kng00000gp/T/ipykernel_93093/945614756.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=elements, y=counts, palette="mako")

# %%
number_of_elements = df["Number of Elements"]
number_of_elements_counts = {}
for element_count in number_of_elements:
    if not element_count in number_of_elements_counts:
        number_of_elements_counts[element_count] = 1
    else:
        number_of_elements_counts[element_count] +=1
print(number_of_elements_counts)

sorted_items = sorted(number_of_elements_counts.items(), key=lambda item: item[1], reverse=True)

# Now, extract the keys (amt_of_elements) and values (frequencies) from this sorted list of tuples
amt_of_elements = [item[0] for item in sorted_items]
frequencies = [item[1] for item in sorted_items]

colors = sns.color_palette('pastel')[0:len(frequencies)]

plt.figure(figsize=(8, 8)) # Optional: set figure size
plt.pie(frequencies, labels=amt_of_elements, colors=colors, autopct='%1.1f%%', startangle=90,
        wedgeprops={'edgecolor': 'black', 'linewidth': 1}) # Customize wedges
plt.title('Distribution of Number of Elements')
plt.show()
# Out:
# {3: 27, 5: 19, 10: 2, 6: 5, 4: 1}
